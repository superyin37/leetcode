# %% [markdown]
# <a href="https://colab.research.google.com/github/superyin37/leetcode/blob/main/Leetcode_258_Add_Digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def addDigits(self, num: int) -> int:
        if num == 0: return 0
        return 1 + (num - 1) % 9

'''
class Solution:
    def addDigits(self, num: int) -> int:
        result = 0
        if num // 10 == 0: return num
        while(True):
            result = 0
            while(num // 10 != 0):
                result += num % 10
                num //= 10
            result += num
            if result // 10 == 0: return result
            else: num = result
'''
