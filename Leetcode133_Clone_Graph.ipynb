# %% [markdown]
# <a href="https://colab.research.google.com/github/superyin37/leetcode/blob/main/Leetcode133_Clone_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
# Definition for a Node.
class Node:
    def __init__(self, val = 0, neighbors = None):
        self.val = val
        self.neighbors = neighbors if neighbors is not None else []
"""

from typing import Optional
class Solution:
    def cloneGraph(self, node: Optional['Node']) -> Optional['Node']:
        if not node: return None

        visited = {}
        def dfs(root):

            if root in visited: return visited[root]

            node = Node(root.val)
            visited[root] = node

            for neighbor in root.neighbors:
                node.neighbors.append(dfs(neighbor))

            return node

        return dfs(node)
